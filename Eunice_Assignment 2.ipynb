# %% [markdown]
# # AAI - Bootcamp - Assignment01 -  Eunice- Solution

# %% [markdown]
# ## Question 1
# Use encoding techniques (One hot encoding andbLabel encoding) for the category
# column “Region” and provide your solution in the form ofJupyter notebook file.
# Explain which encoding technique should you use and why?

# %%
import pandas as pd
import numpy as np

# Below are usage from sklearn family that we can use
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

from category_encoders import OneHotEncoder

# %%
df_gapminder=pd.read_csv("gapminder.csv")
#df_gapminder.describe()
df_gapminder.sample(5)
# Out:
#        population  fertility   HIV       CO2  BMI_male     GDP  BMI_female  \
# 124  4.284474e+07       5.54  5.80  0.154673  22.47792  2030.0    130.8328
# 135  2.695272e+07       2.46  0.10  4.476669  25.32054  3733.0    124.3462
# 101  9.029712e+07       3.26  0.06  0.842121  22.87263  5332.0    122.3459
# 114  9.132589e+06       7.06  0.60  0.068219  21.96917   615.0    131.5318
# 58   1.197070e+09       2.64  0.32  1.520849  20.95956  3901.0    123.1274
#
#      life  child_mortality                 Region
# 124  59.7             72.4     Sub-Saharan Africa
# 135  68.7             49.2  Europe & Central Asia
# 101  69.4             33.4    East Asia & Pacific
# 114  56.7            168.5     Sub-Saharan Africa
# 58   64.4             65.6             South Asia

# %%
#df_gapminder.sample(5)
#df_gapminder.shape
df_gapminder.info()
#there are no missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139 entries, 0 to 138
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   population       139 non-null    float64
#  1   fertility        139 non-null    float64
#  2   HIV              139 non-null    float64
#  3   CO2              139 non-null    float64
#  4   BMI_male         139 non-null    float64
#  5   GDP              139 non-null    float64
#  6   BMI_female       139 non-null    float64
#  7   life             139 non-null    float64
#  8   child_mortality  139 non-null    float64
#  9   Region           139 non-null    object
# dtypes: float64(9), object(1)
# memory usage: 11.0+ KB

# %%
#let check the number of categories for Region. we have 6 different regions
#df_gapminder.Region.nunique()
df_gapminder.Region.value_counts()
# Out:
# Europe & Central Asia         41
# Sub-Saharan Africa            40
# America                       27
# East Asia & Pacific           14
# Middle East & North Africa    10
# South Asia                     7
# Name: Region, dtype: int64

# %% [markdown]
# # ## Encoding with One hot encoder

# %%
#(Making a copy of the data set)

df_gapminder_OneHot=df_gapminder.copy()
df_gapminder_OneHot
# Out:
#      population  fertility   HIV        CO2  BMI_male      GDP  BMI_female  \
# 0    34811059.0       2.73   0.1   3.328945  24.59620  12314.0    129.9049
# 1    19842251.0       6.43   2.0   1.474353  22.25083   7103.0    130.1247
# 2    40381860.0       2.24   0.5   4.785170  27.50170  14646.0    118.8915
# 3     2975029.0       1.40   0.1   1.804106  25.35542   7383.0    132.8108
# 4    21370348.0       1.96   0.1  18.016313  27.56373  41312.0    117.3755
# ..          ...        ...   ...        ...       ...      ...         ...
# 134   3350832.0       2.11   0.5   2.489764  26.39123  15317.0    124.2604
# 135  26952719.0       2.46   0.1   4.476669  25.32054   3733.0    124.3462
# 136  86589342.0       1.86   0.4   1.479347  20.91630   4085.0    121.9367
# 137  13114579.0       5.88  13.6   0.148982  20.68321   3039.0    132.4493
# 138  13495462.0       3.85  15.1   0.654323  22.02660   1286.0    131.9745
#
#      life  child_mortality                      Region
# ...

# %%
#applying one hot encoder on collums Region
df_gapminder_one_hot_encoded_data = pd.get_dummies(df_gapminder_OneHot, columns = ['Region'])
df_gapminder_one_hot_encoded_data
# Out:
#      population  fertility   HIV        CO2  BMI_male      GDP  BMI_female  \
# 0    34811059.0       2.73   0.1   3.328945  24.59620  12314.0    129.9049
# 1    19842251.0       6.43   2.0   1.474353  22.25083   7103.0    130.1247
# 2    40381860.0       2.24   0.5   4.785170  27.50170  14646.0    118.8915
# 3     2975029.0       1.40   0.1   1.804106  25.35542   7383.0    132.8108
# 4    21370348.0       1.96   0.1  18.016313  27.56373  41312.0    117.3755
# ..          ...        ...   ...        ...       ...      ...         ...
# 134   3350832.0       2.11   0.5   2.489764  26.39123  15317.0    124.2604
# 135  26952719.0       2.46   0.1   4.476669  25.32054   3733.0    124.3462
# 136  86589342.0       1.86   0.4   1.479347  20.91630   4085.0    121.9367
# 137  13114579.0       5.88  13.6   0.148982  20.68321   3039.0    132.4493
# 138  13495462.0       3.85  15.1   0.654323  22.02660   1286.0    131.9745
#
# ...

# %%
df_gapminder_one_hot_encoded_data.shape
# new shape (139, 15)
# Out:
# (139, 15)

# %% [markdown]
# we see that the shape of the data set has changed we now have 15 features out of 10 that were there previously

# %% [markdown]
# ### Enconding with Label Encoder

# %%
#Using Category Codes Approach
#(Making a copy of the data set)

df_gapminder_category_codes=df_gapminder.copy()
df_gapminder_category_codes
# Out:
#      population  fertility   HIV        CO2  BMI_male      GDP  BMI_female  \
# 0    34811059.0       2.73   0.1   3.328945  24.59620  12314.0    129.9049
# 1    19842251.0       6.43   2.0   1.474353  22.25083   7103.0    130.1247
# 2    40381860.0       2.24   0.5   4.785170  27.50170  14646.0    118.8915
# 3     2975029.0       1.40   0.1   1.804106  25.35542   7383.0    132.8108
# 4    21370348.0       1.96   0.1  18.016313  27.56373  41312.0    117.3755
# ..          ...        ...   ...        ...       ...      ...         ...
# 134   3350832.0       2.11   0.5   2.489764  26.39123  15317.0    124.2604
# 135  26952719.0       2.46   0.1   4.476669  25.32054   3733.0    124.3462
# 136  86589342.0       1.86   0.4   1.479347  20.91630   4085.0    121.9367
# 137  13114579.0       5.88  13.6   0.148982  20.68321   3039.0    132.4493
# 138  13495462.0       3.85  15.1   0.654323  22.02660   1286.0    131.9745
#
#      life  child_mortality                      Region
# ...

# %%
#change Region data type to category
df_gapminder_category_codes['Region'] = df_gapminder_category_codes['Region'].astype('category')

df_gapminder_category_codes['Region'] = df_gapminder_category_codes['Region'].cat.codes

df_gapminder_category_codes.Region.value_counts(ascending=True)
# Out:
# 4     7
# 3    10
# 1    14
# 0    27
# 5    40
# 2    41
# Name: Region, dtype: int64

# %% [markdown]
# ### Explaining which encoding technique to  use and why

# %% [markdown]
# I will use the Label encoding since it does affect the dimension of the data set. Again because for  Region  the order of data is not necessary.

# %% [markdown]
# ## Question 2
#  Do you think feature scaling is required? If yes - Why, If no - why?

# %%
### Question 2
import numpy as np
df_wine=pd.read_csv("wine_data_UCI.csv")
df_wine.describe()
# Out:
#           quality     Alcohol   Malicacid         Ash  Alcalinity_of_ash  \
# count  178.000000  178.000000  178.000000  178.000000         178.000000
# mean     1.938202   13.000618    2.336348    2.366517          19.494944
# std      0.775035    0.811827    1.117146    0.274344           3.339564
# min      1.000000   11.030000    0.740000    1.360000          10.600000
# 25%      1.000000   12.362500    1.602500    2.210000          17.200000
# 50%      2.000000   13.050000    1.865000    2.360000          19.500000
# 75%      3.000000   13.677500    3.082500    2.557500          21.500000
# max      3.000000   14.830000    5.800000    3.230000          30.000000
#
#         Magnesium  Total_phenols  Flavanoids  Nonflavanoid_phenols  \
# count  178.000000     178.000000  178.000000            178.000000
# mean    99.741573       2.295112    2.029270              0.361854
# std     14.282484       0.625851    0.998859              0.124453
# ...

# %%
df_wine.sample(5)
# Out:
#     quality  Alcohol  Malicacid   Ash  Alcalinity_of_ash  Magnesium  \
# 2         1    13.16       2.36  2.67               18.6        101
# 82        2    12.08       1.13  2.51               24.0         78
# 6         1    14.39       1.87  2.45               14.6         96
# 31        1    13.58       1.66  2.36               19.1        106
# 11        1    14.12       1.48  2.32               16.8         95
#
#     Total_phenols  Flavanoids  Nonflavanoid_phenols  Proanthocyanins  \
# 2            2.80        3.24                  0.30             2.81
# 82           2.00        1.58                  0.40             1.40
# 6            2.50        2.52                  0.30             1.98
# 31           2.86        3.19                  0.22             1.95
# 11           2.20        2.43                  0.26             1.57
#
#     Color_intensity   Hue  0D280_0D315_of_diluted_wines  Proline
# 2              5.68  1.03                          3.17     1185
# ...

# %%
df_wine.quality.value_counts()
#see the 3 classes of wine quality
# Out:
# 2    71
# 1    59
# 3    48
# Name: quality, dtype: int64

# %%
#let drop the other features on focus on quality, Alcohol and Mmmmaicacid

New_df_wine= df_wine[ ["quality","Alcohol","Malicacid"]]
New_df_wine
# Out:
#      quality  Alcohol  Malicacid
# 0          1    14.23       1.71
# 1          1    13.20       1.78
# 2          1    13.16       2.36
# 3          1    14.37       1.95
# 4          1    13.24       2.59
# ..       ...      ...        ...
# 173        3    13.71       5.65
# 174        3    13.40       3.91
# 175        3    13.27       4.28
# 176        3    13.17       2.59
# 177        3    14.13       4.10
#
# [178 rows x 3 columns]

# %%
New_df_wine.describe()
# Out:
#           quality     Alcohol   Malicacid
# count  178.000000  178.000000  178.000000
# mean     1.938202   13.000618    2.336348
# std      0.775035    0.811827    1.117146
# min      1.000000   11.030000    0.740000
# 25%      1.000000   12.362500    1.602500
# 50%      2.000000   13.050000    1.865000
# 75%      3.000000   13.677500    3.082500
# max      3.000000   14.830000    5.800000

# %%
Feature scaling is needed because the Alcohol and Malicacid recored in differents scales.

# %%
plt.scatter(y_Alcohol,y_Malicacid,  color="blue", label="data with no scaling",alpha=0.5)

# %%
import matplotlib.pyplot as plt
#checking for outlier
#let check outliers with dotplot quality and Alcohol
x_quality = New_df_wine["quality"]
y_Alcohol = New_df_wine["Alcohol"]
plt.scatter(x_quality ,y_Alcohol)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#checking the distrubtion of the  data
y_Alcohol.hist()
# Out:
# <AxesSubplot:>

# %%
#let check outliers with dotplot quality and Alcohol
x_quality = New_df_wine["quality"]
y_Malicacid = New_df_wine["Malicacid"]
plt.scatter(x_quality ,y_Malicacid )
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
y_Malicacid.hist()
#not normaly distributed
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Question 3
#  If you feel feature scaling is required, then perform Standardization and Normalization and provide your result. What is the difference you observe between these two methods?

# %%
#Normaliszation 
X_Alcohol=New_df_wine["Alcohol"]
y_Malicacid = New_df_wine["Malicacid"]
X_Alcohol=X_Alcohol.to_numpy()
y_Malicacid =y_Malicacid .to_numpy()

# %%
from sklearn.preprocessing import Normalizer
normalizer = Normalizer().fit([X_Alcohol])
normalizer.transform([X_Alcohol]).mean()
# Out:
# 0.07480827469396367

# %%
normalizer = Normalizer().fit([y_Malicacid])
normalizer.transform([y_Malicacid]).mean()
# Out:
# 0.06765587278178141

# %%
the mean for both featrures are now closer unlike in the non normalized data set both close to 0.7

# %%
#standardization 
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit_transform([X_Alcohol])
df_transformed_X=sc.transform([X_Alcohol])
sc.fit_transform([y_Malicacid])
df_transformed_y=sc.transform([y_Malicacid])

print(df_transformed_X.mean())
print(df_transformed_y.mean())
# Out:
# 0.0
# 0.0

# %%
Using standard scaltter again rthe mean for both are also the same here both are 0

# %%
#minMax scaling 
df = (New_df_wine-New_df_wine.min())/(New_df_wine.max()-New_df_wine.min())
print(df)
# Out:
#      quality   Alcohol  Malicacid
# 0        0.0  0.842105   0.191700
# 1        0.0  0.571053   0.205534
# 2        0.0  0.560526   0.320158
# 3        0.0  0.878947   0.239130
# 4        0.0  0.581579   0.365613
# ..       ...       ...        ...
# 173      1.0  0.705263   0.970356
# 174      1.0  0.623684   0.626482
# 175      1.0  0.589474   0.699605
# 176      1.0  0.563158   0.365613
# 177      1.0  0.815789   0.664032
#
# [178 rows x 3 columns]

# %%
df.describe()
#after scalling the min for alcohoal  and malicacid is 0 and the max for both  is 1
#the mean and standard deviation are also closer than in the non scalled data set.
# Out:
#           quality     Alcohol   Malicacid
# count  178.000000  178.000000  178.000000
# mean     0.469101    0.518584    0.315484
# std      0.387517    0.213639    0.220780
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.350658    0.170455
# 50%      0.500000    0.531579    0.222332
# 75%      1.000000    0.696711    0.462945
# max      1.000000    1.000000    1.000000

# %% [markdown]
# # Question 4
#
# Not done
#
# Facebook has a content team that labels pieces of content on the platform as spam or not spam.
# 90% of them are diligent raters and will correctly label 95% of the time.
# The remaining 10% are non-diligent raters and will label 50% of the content incorrectly.
# Assume the pieces of content are labeled independently from one another, for every rater.
# Given that a piece has been rated as non-spam, what is the probability that is it actually non-spam?
#
# Diligent raters
#  0.9	Non diligent
# 0.1
# Correct spam
#  0.95	Incorrect non spam 0.05	Correct spam
# 0.5	incorrect
# 0.5
#
# Given that the piece is rated non-spam
# Probability that it is non span
# P(A/B)
# Event A: a piece has been rated as non-spam
# Event B: is a piece is actually a-non spam
# Let use bayes theorem
# P(A⁄B)=(P(B⁄A)*P(A))/P(B)
# Calculates some probability
#
# P(B⁄A): P(probability )
# P(A): Pro
# P(B): Probability of piece being rated as spam by either the diligent or non diligent
# P(B)=P()

# %% [markdown]
# # Question 5  and # Question 6 ![Question%205-6.jpeg](attachment:Question%205-6.jpeg)
